# %%
from sklearn import naive_bayes
import nltk
import numpy as np
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %%
# load data file into a pandas data frame
df = pd.read_csv('data.csv', sep=',', names=['emotion', 'lyrics'])

# shuffle and preview data frame
df.sample(frac=1)
# Out:
#      emotion                                             lyrics
# 399      sad   If you called and I didn't answer There's a c...
# 369      sad   Walking across the sitting-room I turn the te...
# 779    happy   I got these fresh eyes never seen you before ...
# 387      sad   You won't see me crying Crying over you And y...
# 1212   happy   I won't lie to you I know he's just not right...
# 180      sad   I met a girl last night had short blonde hair...
# 62       sad   I miss the old you The one that held me down ...
# 560      sad   I won't lie to you I know he's just not right...
# 1110   happy   You shout it out But I can't hear a word you ...
# 183      sad   Scott Storch  Ooh so they think I wanna die y...
# 251      sad   Mercedes (Artie): (Clap your hands y'all it's...
# 6        sad   When you're dreaming with a broken heart  The...
# 1196   happy   It was all a dream I used to read Word Up mag...
# 958    happy   Every butterfly I get belongs to you You don'...
# 1244   happy   I spend my money on the regular miracles Just...
# 1108   happy   Chained to a love But that don't mean much Se...
# 138      sad   Remember those walls I built? Well baby they'...
# 303      sad   The last time that I saw you You were headed ...
# 798    happy   Time goes by And I've been holding everything...
# 943    happy   I used to believe We were burnin' on the edge...
# 1275   happy   First things first I'mma say all the words in...
# 1256   happy   Nine... four... eight... one. B'Day.  Swizz B...
# 824    happy   You're beautiful and that's for sure You'll n...
# 682    happy   Normani: Every day is pay day swipe my card t...
# 1305   happy   When I need motivation My one solution is my ...
# 554      sad   I'm not a perfect person There's many things ...
# 751    happy   You  She's tried on everything Every little t...
# 1086   happy   He's got a thing for fitness seven days a wee...
# 178      sad   So this is where we are It's not where we had...
# 644      sad   I've conjured up a plan as a sentimental man ...
# ...      ...                                                ...
# 52       sad   Do you know what's worth fighting for When it...
# 816    happy   (Feat. 3LW)  [3LW] Oh... hey Naughty...  (Tre...
# 1056   happy   Saturday morning jumped out of bed And put on...
# 21       sad   Members Only Volume... Volume 3 Uh  Won't fal...
# 509      sad   I know that we are upside down So hold your t...
# 1250   happy   In a few weeks I will get time To realise it'...
# 817    happy   Know that I been waiting for so long! You're ...
# 1039   happy   Everybody gets high sometimes ya know? What e...
# 428      sad   I see you out in places Almost every night my...
# 261      sad   I wish I could tie you up in my shoes Make yo...
# 1197   happy   Everybody feels the same way yeah I know you ...
# 392      sad   All I need is a little love in my life All I ...
# 235      sad   Watch this...  These are my confessions Just ...
# 1063   happy   I don't know why  You think that you could ho...
# 479      sad   You called me out and taught me tough With lo...
# 1065   happy   What you find-ah What you feel now What you k...
# 294      sad   Your hand fits in mine Like it's made just fo...
# 1295   happy   I'm so into you I can barely breathe And all ...
# 354      sad   Here we are we are the champions We've come s...
# 1082   happy   Some legends are told some turn to dust or to...
# 810    happy   I was just an only child of the universe And ...
# 1117   happy   This Baha Men And we gonna kick it like this ...
# 408      sad   I fought for you The hardest it made me the s...
# 1046   happy   Ooh (you got- you got- you got- you)  You've ...
# 219      sad   Merrily we fall Out of line out of line I'd f...
# 899    happy   She played the fiddle in an Irish band But sh...
# 853    happy   Sunlight on your eyelids You were sleeping Ah...
# 481      sad   For all the times that you rained on my parad...
# 255      sad   It's a small town word gets around And travel...
# 1029   happy   Unfortunately we are not licensed to display ...
#
# [1338 rows x 2 columns]

# %%
# process text data into vectors
stopset = set(stopwords.words('english'))
vectorizer = TfidfVectorizer(use_idf=True, lowercase=True, strip_accents='ascii', stop_words=stopset)
y = df.emotion
X = vectorizer.fit_transform(df.lyrics)
print(y.shape)
print(X.shape)
# Out:
# (1338,)
# (1338, 11317)

# %%
# split into training and testing subsets and train the model

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

classifier = naive_bayes.MultinomialNB()
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# test model's accuracy
roc_auc_score(y_test, classifier.predict_proba(X_test)[:,1])
# Out:
# 0.749371754062657

# %%
# dump the vectorizer and trained classifier
joblib.dump(vectorizer, 'vectorizer.pk1')
joblib.dump(classifier, 'classifier.pk1')
# Out:
# ['classifier.pk1']

# %%
# sanity test
st_array = np.array(["I heard that you're settled down That you found a girl and you're married now I heard that your dreams came true Guess she gave you things I didn't give to you  Old friend, why are you so shy? Ain't like you to hold back or hide from the light  I hate to turn up out of the blue, uninvited But I couldn't stay away, I couldn't fight it I had hoped you'd see my face and that you'd be reminded That for me, it isn't over  Never mind, I'll find someone like you I wish nothing but the best for you two Don't forget me, I beg, I'll remember you said Sometimes it lasts in love, but sometimes it hurts instead Sometimes it lasts in love, but sometimes it hurts instead, yeah  You know how the time flies Only yesterday was the time of our lives We were born and raised in a summer haze Bound by the surprise of our glory days  I hate to turn up out of the blue, uninvited But I couldn't stay away, I couldn't fight it I had hoped you'd see my face and that you'd be reminded That for me, it isn't over  Never mind, I'll find someone like you I wish nothing but the best for you two Don't forget me, I beg, I'll remember you said Sometimes it lasts in love, but sometimes it hurts instead Nothing compares, no worries or cares  Regrets and mistakes, they're memories made Who would have known how bittersweet this would taste? Never mind, I'll find someone like you  I wish nothing but the best for you Don't forget me, I beg, I'll remember you said Sometimes it lasts in love, but sometimes it hurts instead Never mind, I'll find someone like you I wish nothing but the best for you two Don't forget me, I beg, I'll remember you said Sometimes it lasts in love, but sometimes it hurts instead Sometimes it lasts in love, but sometimes it hurts instead, yeah"])
st_vector = vectorizer.transform(st_array)
print(classifier.predict(st_vector))
# Out:
# ['sad']
